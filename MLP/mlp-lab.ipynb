# %% [markdown]
# # Lab 11: Multilayer perceptron classification using *scikit-learn*
#
#
# ### Add your name to the markdown cell below <span style = 'font-size:80%'>[2 points]</span>

# %% [markdown]
# ### Name: Juan Villegas

# %% [markdown]
# ## Using a perceptron to for classification of a small example dataset
#
# A small, made up dataset is provided below, and is composed of the following:
#
# - *X*: the feature matrix consisting of 100 values for one variable
# - *y*: the target values, consisting of either 0 or 1
#
# Note that you do not need to understand the code; only that the code creates the feature matrix *X* and the target values *y*.

# %%
import numpy as np

# Generate X values from 1 - 100
X = np.arange(1,101)

# Generate corresponding target values which are to 1 if the feature > 50; or 0 otherwise
l = [int(x > 50) for x in X]
y = np.array(l)

# X must be 2-dimensional for scikit learn, so reshape the data
X = X.reshape((100, 1))

# %% [markdown]
# ### Question 1 <span style = 'font-size:80%'>[5 points]</span>
#
# Use the seaborn module to generate a scatterplot that plots the first column of X on the x-axis and the number 0 on the y-axis (the second argument should simply be 0), and color the points by *y* value. The plot should look like the plot below (but don't worry if you are unable to set the x- and y-axis labels):
#
# ![image.png](attachment:image.png)

# %%
import seaborn as sns
s = sns.scatterplot(x = X[:,0], y = X[:,0], hue = y)
None

# %% [markdown]
# The code below fits a *Perceptron* classifier to the data. As covered in class, a perceptron consist of an input layer, a single neuron, and an output layer. The single neuron fires if the sum of weighted inputs is greater than the bias term.

# %%
from sklearn.linear_model import Perceptron

perceptron = Perceptron(max_iter=5000, random_state = 1, tol = 1e-10)
perceptron.fit(X,y)
# Out:
# Perceptron(max_iter=5000, random_state=1, tol=1e-10)

# %% [markdown]
# ### Question 2 <span style = 'font-size:80%'>[6 points]</span>
#
# Show that the perceptron fits the training data with 100% accuracy, by creating a heatmap showing the confusion matrix for predictions on the training data.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

confusion = confusion_matrix(y_true = y_test, y_pred = y_pred)
s = sns.heatmap(confusion, annot = True, cmap = 'nipy_spectral_r', fmt='.3g')
s.set_title('Confusion matrix for Breast Cancer dataset')
s.set_ylabel('true value')
s.set_xlabel('predicted value')
None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4d/q5zngvpn4yd8kq0w166v0b8c0000gn/T/ipykernel_2282/976754201.py in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2 import seaborn as sns
# ----> 3 confusion = confusion_matrix(y_true = y_test, y_pred = y_pred)
#       4 s = sns.heatmap(confusion, annot = True, cmap = 'nipy_spectral_r', fmt='.3g')
#       5 s.set_title('Confusion matrix for Breast Cancer dataset')
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ### Question 3 <span style = 'font-size:80%'>[5 points]</span>
#
# The weight and bias term for the neuron are displayed below. Based on the weight and bias term, when does the neuron fire? Answer in the markdown cell below. Given the graph of the data from Question 1 (and using a little bit of algebra), does this make sense? Why or why not?
#
# (Note: the intercept has the opposite sign of the bias term that we discussed in class; hence we output *-perceptron.intercept_[0]*; this output is the *bias*)

# %%
print('The weight for the first layer is:', perceptron.coef_[0][0])
print('The bias for the first layer is: ', -perceptron.intercept_[0])
# Out:
# The weight for the first layer is: 5.0
# The bias for the first layer is:  251.0

# %% [markdown]
# Answer:

# %% [markdown]
# ## Multilayer perceptron on the MNIST dataset
#
# We will now use a multilayer perceptron to classify the MNIST dataset, considering all 10 digits.
#
# ### Load the data

# %%
from sklearn import datasets
digits = datasets.load_digits()
X = digits.data
y = digits.target

# %% [markdown]
# ### Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=21, stratify = y)

# %% [markdown]
# ### Scale the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scaler on the training data
scaler.fit(X_train)

# then user the scaler to scale the training and testing data 
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Fit the model

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=10, max_iter=1000, verbose = True, random_state=211)
mlp.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 2.74540919
# Iteration 2, loss = 2.63291155
# Iteration 3, loss = 2.53893898
# Iteration 4, loss = 2.45499963
# Iteration 5, loss = 2.37702922
# Iteration 6, loss = 2.30462789
# Iteration 7, loss = 2.23709343
# Iteration 8, loss = 2.17336514
# Iteration 9, loss = 2.11300093
# Iteration 10, loss = 2.05489909
# Iteration 11, loss = 1.99921418
# Iteration 12, loss = 1.94758963
# Iteration 13, loss = 1.89822233
# Iteration 14, loss = 1.84959197
# Iteration 15, loss = 1.80068534
# Iteration 16, loss = 1.75355558
# Iteration 17, loss = 1.70929121
# Iteration 18, loss = 1.66634070
# Iteration 19, loss = 1.62500886
# Iteration 20, loss = 1.58443987
# Iteration 21, loss = 1.54503098
# Iteration 22, loss = 1.50738184
# Iteration 23, loss = 1.47183337
# Iteration 24, loss = 1.43907056
# Iteration 25, loss = 1.40742841
# Iteration 26, loss = 1.37584262
# Iteration 27, loss = 1.34418328
# Iteration 28, loss = 1.31393048
# Iteration 29, loss = 1.28515168
# Iteration 30, loss = 1.25768453
# Iteration 31, loss = 1.23151753
# Iteration 32, loss = 1.20582650
# Iteration 33, loss = 1.18160940
# Iteration 34, loss = 1.15881013
# Iteration 35, loss = 1.13722036
# Iteration 36, loss = 1.11692403
# Iteration 37, loss = 1.09679768
# Iteration 38, loss = 1.07732618
# Iteration 39, loss = 1.05752667
# Iteration 40, loss = 1.03739382
# Iteration 41, loss = 1.01871857
# Iteration 42, loss = 1.00113417
# Iteration 43, loss = 0.98473794
# Iteration 44, loss = 0.96809081
# Iteration 45, loss = 0.95189950
# Iteration 46, loss = 0.93611905
# Iteration 47, loss = 0.92140584
# Iteration 48, loss = 0.90659443
# Iteration 49, loss = 0.89182346
# Iteration 50, loss = 0.87739636
# Iteration 51, loss = 0.86342239
# Iteration 52, loss = 0.84978798
# Iteration 53, loss = 0.83619052
# Iteration 54, loss = 0.82276251
# Iteration 55, loss = 0.80920533
# Iteration 56, loss = 0.79587493
# Iteration 57, loss = 0.78290898
# Iteration 58, loss = 0.77046174
# Iteration 59, loss = 0.75822895
# Iteration 60, loss = 0.74615527
# Iteration 61, loss = 0.73374084
# Iteration 62, loss = 0.72149176
# Iteration 63, loss = 0.71006115
# Iteration 64, loss = 0.69824528
# Iteration 65, loss = 0.68674313
# Iteration 66, loss = 0.67557006
# Iteration 67, loss = 0.66451346
# Iteration 68, loss = 0.65368864
# Iteration 69, loss = 0.64299884
# Iteration 70, loss = 0.63226858
# Iteration 71, loss = 0.62200799
# Iteration 72, loss = 0.61177947
# Iteration 73, loss = 0.60173880
# Iteration 74, loss = 0.59220257
# Iteration 75, loss = 0.58278930
# Iteration 76, loss = 0.57331442
# Iteration 77, loss = 0.56387781
# Iteration 78, loss = 0.55466331
# Iteration 79, loss = 0.54580081
# Iteration 80, loss = 0.53690887
# Iteration 81, loss = 0.52806062
# Iteration 82, loss = 0.51943063
# Iteration 262, loss = 0.09493315
# Iteration 263, loss = 0.09467857
# Iteration 264, loss = 0.09398406
# Iteration 265, loss = 0.09351746
# Iteration 266, loss = 0.09288646
# Iteration 267, loss = 0.09218420
# Iteration 268, loss = 0.09147724
# Iteration 269, loss = 0.09062125
# Iteration 270, loss = 0.08996628
# Iteration 271, loss = 0.08926276
# Iteration 272, loss = 0.08859938
# Iteration 273, loss = 0.08795976
# Iteration 274, loss = 0.08744922
# Iteration 275, loss = 0.08698588
# Iteration 276, loss = 0.08644353
# Iteration 277, loss = 0.08594669
# Iteration 278, loss = 0.08538865
# Iteration 279, loss = 0.08488392
# Iteration 280, loss = 0.08438423
# Iteration 281, loss = 0.08388828
# Iteration 282, loss = 0.08366763
# Iteration 283, loss = 0.08332861
# Iteration 284, loss = 0.08301015
# Iteration 285, loss = 0.08257610
# Iteration 286, loss = 0.08210081
# Iteration 287, loss = 0.08175379
# Iteration 288, loss = 0.08117110
# Iteration 289, loss = 0.08082333
# Iteration 290, loss = 0.08040428
# Iteration 291, loss = 0.07984715
# Iteration 292, loss = 0.07936914
# Iteration 293, loss = 0.07881856
# Iteration 294, loss = 0.07832556
# Iteration 295, loss = 0.07786984
# Iteration 296, loss = 0.07745443
# Iteration 297, loss = 0.07705113
# Iteration 298, loss = 0.07659257
# Iteration 299, loss = 0.07619022
# Iteration 300, loss = 0.07574132
# Iteration 301, loss = 0.07529480
# Iteration 302, loss = 0.07487066
# Iteration 303, loss = 0.07451689
# Iteration 304, loss = 0.07415652
# Iteration 305, loss = 0.07373173
# Iteration 306, loss = 0.07339425
# Iteration 307, loss = 0.07301022
# Iteration 308, loss = 0.07273722
# Iteration 309, loss = 0.07231446
# Iteration 310, loss = 0.07202141
# Iteration 311, loss = 0.07168986
# Iteration 312, loss = 0.07132898
# Iteration 313, loss = 0.07096059
# Iteration 314, loss = 0.07059499
# Iteration 315, loss = 0.07020999
# Iteration 316, loss = 0.06984917
# Iteration 317, loss = 0.06945223
# Iteration 318, loss = 0.06890741
# Iteration 319, loss = 0.06856297
# Iteration 320, loss = 0.06828503
# Iteration 321, loss = 0.06795574
# Iteration 322, loss = 0.06759287
# Iteration 323, loss = 0.06722289
# Iteration 324, loss = 0.06690636
# Iteration 325, loss = 0.06658026
# Iteration 326, loss = 0.06627943
# Iteration 327, loss = 0.06599503
# Iteration 328, loss = 0.06568061
# Iteration 329, loss = 0.06535969
# Iteration 330, loss = 0.06504345
# Iteration 331, loss = 0.06469806
# Iteration 332, loss = 0.06439405
# Iteration 333, loss = 0.06407896
# Iteration 334, loss = 0.06377254
# Iteration 335, loss = 0.06343015
# Iteration 336, loss = 0.06316344
# Iteration 337, loss = 0.06287230
# Iteration 338, loss = 0.06255780
# Iteration 339, loss = 0.06230074
# Iteration 340, loss = 0.06202222
# Iteration 341, loss = 0.06176971
# Iteration 342, loss = 0.06149340
# Iteration 343, loss = 0.06120311
# Iteration 344, loss = 0.06089851
# Iteration 345, loss = 0.06068909
# Iteration 346, loss = 0.06048835
# Iteration 347, loss = 0.06029179
# Iteration 348, loss = 0.06007344
# Iteration 349, loss = 0.05974240
# Iteration 350, loss = 0.05948203
# Iteration 351, loss = 0.05906445
# Iteration 352, loss = 0.05911974
# Iteration 353, loss = 0.05886634
# Iteration 354, loss = 0.05863991
# Iteration 355, loss = 0.05831356
# Iteration 356, loss = 0.05803070
# Iteration 357, loss = 0.05767159
# Iteration 358, loss = 0.05727321
# Iteration 359, loss = 0.05699067
# Iteration 360, loss = 0.05668701
# Iteration 361, loss = 0.05638227
# Iteration 362, loss = 0.05612994
# Iteration 363, loss = 0.05584274
# Iteration 364, loss = 0.05552928
# Iteration 365, loss = 0.05539524
# Iteration 366, loss = 0.05514297
# Iteration 367, loss = 0.05492012
# Iteration 368, loss = 0.05468133
# Iteration 369, loss = 0.05442631
# Iteration 370, loss = 0.05414280
# Iteration 371, loss = 0.05389040
# Iteration 372, loss = 0.05372766
# Iteration 373, loss = 0.05360459
# Iteration 374, loss = 0.05355982
# Iteration 375, loss = 0.05331661
# Iteration 376, loss = 0.05303681
# Iteration 377, loss = 0.05273079
# Iteration 378, loss = 0.05247566
# Iteration 379, loss = 0.05223785
# Iteration 380, loss = 0.05195650
# Iteration 381, loss = 0.05167316
# Iteration 382, loss = 0.05139127
# Iteration 383, loss = 0.05105773
# Iteration 384, loss = 0.05093053
# Iteration 385, loss = 0.05068833
# Iteration 386, loss = 0.05046104
# Iteration 387, loss = 0.05026922
# Iteration 388, loss = 0.05001927
# Iteration 389, loss = 0.04980695
# Iteration 390, loss = 0.04955375
# Iteration 391, loss = 0.04934311
# Iteration 392, loss = 0.04909794
# Iteration 393, loss = 0.04888840
# Iteration 394, loss = 0.04860831
# Iteration 395, loss = 0.04894052
# Iteration 396, loss = 0.04910947
# Iteration 397, loss = 0.04912802
# Iteration 398, loss = 0.04905859
# Iteration 399, loss = 0.04874670
# Iteration 400, loss = 0.04828940
# Iteration 401, loss = 0.04791654
# Iteration 402, loss = 0.04750763
# Iteration 403, loss = 0.04717511
# Iteration 404, loss = 0.04683288
# Iteration 405, loss = 0.04658876
# Iteration 406, loss = 0.04625471
# Iteration 407, loss = 0.04600450
# Iteration 408, loss = 0.04582201
# Iteration 409, loss = 0.04567898
# Iteration 410, loss = 0.04543408
# Iteration 411, loss = 0.04521112
# Iteration 412, loss = 0.04498158
# Iteration 413, loss = 0.04474905
# Iteration 414, loss = 0.04450531
# Iteration 415, loss = 0.04418136
# Iteration 416, loss = 0.04397056
# Iteration 417, loss = 0.04384231
# Iteration 418, loss = 0.04391905
# Iteration 419, loss = 0.04383736
# Iteration 420, loss = 0.04360214
# Iteration 421, loss = 0.04332987
# Iteration 422, loss = 0.04306320
# Iteration 423, loss = 0.04282898
# Iteration 424, loss = 0.04259393
# Iteration 425, loss = 0.04236226
# Iteration 426, loss = 0.04238031
# Iteration 427, loss = 0.04238503
# Iteration 428, loss = 0.04220915
# Iteration 429, loss = 0.04195301
# Iteration 430, loss = 0.04172586
# Iteration 431, loss = 0.04147756
# Iteration 432, loss = 0.04116166
# Iteration 433, loss = 0.04091412
# Iteration 434, loss = 0.04072970
# Iteration 435, loss = 0.04053218
# Iteration 436, loss = 0.04034860
# Iteration 437, loss = 0.04013787
# Iteration 438, loss = 0.03995236
# Iteration 439, loss = 0.03971965
# Iteration 440, loss = 0.03955069
# Iteration 441, loss = 0.03937316
# Iteration 442, loss = 0.03924777
# Iteration 443, loss = 0.03911841
# Iteration 444, loss = 0.03896115
# Iteration 445, loss = 0.03873241
# Iteration 446, loss = 0.03856025
# Iteration 447, loss = 0.03837736
# Iteration 448, loss = 0.03816496
# Iteration 449, loss = 0.03796668
# Iteration 450, loss = 0.03778104
# Iteration 451, loss = 0.03759868
# Iteration 452, loss = 0.03741321
# Iteration 453, loss = 0.03723926
# Iteration 454, loss = 0.03711207
# Iteration 455, loss = 0.03695501
# Iteration 456, loss = 0.03679942
# Iteration 457, loss = 0.03663290
# Iteration 458, loss = 0.03646090
# Iteration 459, loss = 0.03622265
# Iteration 460, loss = 0.03612632
# Iteration 461, loss = 0.03602811
# Iteration 462, loss = 0.03593886
# Iteration 463, loss = 0.03579979
# Iteration 464, loss = 0.03564381
# Iteration 465, loss = 0.03549264
# Iteration 466, loss = 0.03526241
# Iteration 467, loss = 0.03511146
# Iteration 468, loss = 0.03498709
# Iteration 469, loss = 0.03490463
# Iteration 470, loss = 0.03464993
# Iteration 471, loss = 0.03447454
# Iteration 472, loss = 0.03435148
# Iteration 473, loss = 0.03419956
# Iteration 474, loss = 0.03400021
# Iteration 475, loss = 0.03374081
# Iteration 476, loss = 0.03387534
# Iteration 477, loss = 0.03382417
# Iteration 478, loss = 0.03367060
# Iteration 479, loss = 0.03349215
# Iteration 480, loss = 0.03332006
# Iteration 481, loss = 0.03306500
# Iteration 482, loss = 0.03321683
# Iteration 483, loss = 0.03344255
# Iteration 484, loss = 0.03349978
# Iteration 485, loss = 0.03333604
# Iteration 486, loss = 0.03308529
# Iteration 487, loss = 0.03279675
# Iteration 488, loss = 0.03252209
# Iteration 489, loss = 0.03231233
# Iteration 490, loss = 0.03233651
# Iteration 491, loss = 0.03231230
# Iteration 492, loss = 0.03215718
# Iteration 493, loss = 0.03196952
# Iteration 494, loss = 0.03176269
# Iteration 495, loss = 0.03159389
# Iteration 496, loss = 0.03128586
# Iteration 497, loss = 0.03129801
# Iteration 498, loss = 0.03133336
# Iteration 499, loss = 0.03124772
# Iteration 500, loss = 0.03104630
# Iteration 501, loss = 0.03080843
# Iteration 502, loss = 0.03056674
# Iteration 503, loss = 0.03036799
# Iteration 504, loss = 0.03008248
# Iteration 505, loss = 0.02986584
# Iteration 506, loss = 0.02970400
# Iteration 507, loss = 0.02956621
# Iteration 508, loss = 0.02943496
# Iteration 509, loss = 0.02932671
# Iteration 510, loss = 0.02919764
# Iteration 511, loss = 0.02905005
# Iteration 512, loss = 0.02890192
# Iteration 513, loss = 0.02919552
# Iteration 514, loss = 0.02917241
# Iteration 515, loss = 0.02929615
# Iteration 516, loss = 0.02923119
# Iteration 517, loss = 0.02913957
# Iteration 518, loss = 0.02890021
# Iteration 519, loss = 0.02874918
# Iteration 520, loss = 0.02849076
# Iteration 521, loss = 0.02829849
# Iteration 522, loss = 0.02806512
# Iteration 523, loss = 0.02788685
# Iteration 524, loss = 0.02771769
# Iteration 525, loss = 0.02754795
# Iteration 526, loss = 0.02737800
# Iteration 527, loss = 0.02724205
# Iteration 528, loss = 0.02711176
# Iteration 529, loss = 0.02700310
# Iteration 530, loss = 0.02688256
# Iteration 531, loss = 0.02677575
# Iteration 532, loss = 0.02661585
# Iteration 533, loss = 0.02646908
# Iteration 534, loss = 0.02633523
# Iteration 535, loss = 0.02621234
# Iteration 536, loss = 0.02609436
# Iteration 537, loss = 0.02598734
# Iteration 538, loss = 0.02588888
# Iteration 539, loss = 0.02581244
# Iteration 540, loss = 0.02571000
# Iteration 541, loss = 0.02559907
# Iteration 542, loss = 0.02564782
# Iteration 543, loss = 0.02559948
# Iteration 544, loss = 0.02562155
# Iteration 545, loss = 0.02559232
# Iteration 546, loss = 0.02550091
# Iteration 547, loss = 0.02537703
# Iteration 548, loss = 0.02524651
# Iteration 549, loss = 0.02511010
# Iteration 550, loss = 0.02495848
# Iteration 551, loss = 0.02482704
# Iteration 552, loss = 0.02466633
# Iteration 553, loss = 0.02453483
# Iteration 554, loss = 0.02440932
# Iteration 555, loss = 0.02429484
# Iteration 556, loss = 0.02418143
# Iteration 557, loss = 0.02405907
# Iteration 558, loss = 0.02395690
# Iteration 559, loss = 0.02384140
# Iteration 560, loss = 0.02372258
# Iteration 561, loss = 0.02359216
# Iteration 562, loss = 0.02348891
# Iteration 563, loss = 0.02345149
# Iteration 564, loss = 0.02336087
# Iteration 565, loss = 0.02327863
# Iteration 566, loss = 0.02317165
# Iteration 567, loss = 0.02298886
# Iteration 568, loss = 0.02314708
# Iteration 569, loss = 0.02329347
# Iteration 570, loss = 0.02331388
# Iteration 571, loss = 0.02321521
# Iteration 572, loss = 0.02307115
# Iteration 573, loss = 0.02290995
# Iteration 574, loss = 0.02272787
# Iteration 575, loss = 0.02252614
# Iteration 576, loss = 0.02240183
# Iteration 577, loss = 0.02230273
# Iteration 578, loss = 0.02218962
# Iteration 579, loss = 0.02207463
# Iteration 580, loss = 0.02195955
# Iteration 581, loss = 0.02184778
# Iteration 582, loss = 0.02172957
# Iteration 583, loss = 0.02162519
# Iteration 584, loss = 0.02152081
# Iteration 585, loss = 0.02145664
# Iteration 586, loss = 0.02135183
# Iteration 587, loss = 0.02125550
# Iteration 588, loss = 0.02116210
# Iteration 589, loss = 0.02106283
# Iteration 590, loss = 0.02097133
# Iteration 591, loss = 0.02088487
# Iteration 592, loss = 0.02084696
# Iteration 593, loss = 0.02078336
# Iteration 594, loss = 0.02072617
# Iteration 595, loss = 0.02060352
# Iteration 596, loss = 0.02050434
# Iteration 597, loss = 0.02037711
# Iteration 598, loss = 0.02028939
# Iteration 599, loss = 0.02022361
# Iteration 600, loss = 0.02016775
# Iteration 601, loss = 0.02012019
# Iteration 602, loss = 0.02004481
# Iteration 603, loss = 0.01996459
# Iteration 604, loss = 0.01991279
# Iteration 605, loss = 0.01984658
# Iteration 606, loss = 0.01975504
# Iteration 607, loss = 0.01967997
# Iteration 608, loss = 0.01963504
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=10, max_iter=1000, random_state=211,
#               verbose=True)

# %% [markdown]
# ### Plot the loss curve

# %%
import matplotlib.pyplot as plt
plt.plot(mlp.loss_curve_)
plt.xlabel('Number of epochs')
plt.ylabel('loss')
plt.title('The loss curve for our mlp classifier')
None

# %% [markdown]
# ### Make predictions in the *test* dataset

# %%
y_pred = mlp.predict(X_test)

# %% [markdown]
# ### Evaluate the results by looking at the *confusion matrix*

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns
confusion = confusion_matrix(y_true = y_test, y_pred = y_pred)
df = pd.DataFrame(confusion)
s = sns.heatmap(df, annot = True, cmap = 'nipy_spectral_r', )
s.set_title('Confusion matrix for MNIST dataset')
None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4d/q5zngvpn4yd8kq0w166v0b8c0000gn/T/ipykernel_10033/555923019.py in <module>
#       2 from sklearn.metrics import confusion_matrix
#       3 import seaborn as sns
# ----> 4 confusion = confusion_matrix(y_true = y_test, y_pred = y_pred)
#       5 df = pd.DataFrame(confusion)
#       6 s = sns.heatmap(df, annot = True, cmap = 'nipy_spectral_r', )
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# ### Question 4 <span style = 'font-size:80%'>[6 points]</span>
#
# Based on the heatmap above, use Python as a calculator to output the measures below:
#
# (a) the recall of the digit 3

# %% [markdown]
# (b) the precision for the digit 3

# %% [markdown]
# ### Question 5 <span style = 'font-size:80%'>[6 points]</span>
#
# In the test dataset, the 50th value is predicted to be a 3, as shown in the code below. What is the true value of the 50th digit?

# %%
# get 50th value; reshape is needed to maintain 2D format
X50 = X_test[49,].reshape(1,-1)
mlp.predict(X50)

# %% [markdown]
# Output true value of the 50th target value

# %% [markdown]
# Recall that for a test input, the neural network calculates probabilities for each possible target value (0 - 9), and then chooses the target value with highest probability. If the prediction is not correct, the correct target value may still have had a high probability. From the code below, what are the two digits with the highest probabilities?

# %% [markdown]
# ### (answer here)

# %%
p = mlp.predict_proba(X50)
pd.DataFrame(p.round(3))

# %% [markdown]
# ### Question 6 <span style = 'font-size:80%'>[5 points]</span>
#
# We can use cross validation to find the the optimal number of hidden nodes (and layers). Modify the cell below to create a list called *sizes* that contains the values 10, 30, 64, and 100. Then run the code below which evaluates neural networks with 1 hidden layer of each size in the *sizes* list. Note that this may take 1-2 minutes to run.
#
# (In addition, other parameters can be optimized such as the number of epochs and the learning rate, which we will not worry about here -- Neural networks are considerably more complex than *kNN*).

# %%
sizes = [10]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# create an empty list to store accuracies
acc = []

# for each size, create an mlp estimator and find the mean balanced accuracy using 5-fold cross validation
for size in sizes :

    print('training with size = ', size)

    mlp = MLPClassifier(hidden_layer_sizes=size, max_iter=1000, verbose = False, random_state=211)
    
    # create the k = 5 folds
    kfold = KFold(n_splits=5, random_state=99, shuffle = True)
    
    # return an array of scores that contains the balanced accuracy for each fold
    scores = cross_val_score(estimator = mlp, X = digits.data, y = digits.target, cv = kfold, scoring = "balanced_accuracy" )
    print('\tmean balanced accuracy with size = ', size, ': ', scores.mean(), sep = '')

    # add the mean balanced accuracy for the current fold to the list
    acc.append(scores.mean())

# %% [markdown]
# ### Question 7 <span style = 'font-size:80%'>[5 points]</span>
#
# Generate a scatterplot showing the size of hidden layer on the x-axis and the balanced accuracy on the y-axis. Note that after running the code above, the sizes are stored in the list <i>sizes</i> and the balanced accuracies are stored in the list <i>acc</i>. Comment on the optimal size.

# %% [markdown]
# ### Question 8 (optional)
#
# We can improve the neural network slightly by including two layers. Use 5-fold cross-validation to evaluate a multilayer perceptron with 2 hidden layers, that consist of 200 neurons and 10 neurons, respectively. Calculate the mean balanced accuracy. Recall that when specifying the neural network model, that we can set *hidden_layer_sizes* to a list, where the $i^{th}$ element is the number of nodes in the $i^{th}$ hidden layer.
